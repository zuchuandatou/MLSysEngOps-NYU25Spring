# %%
cd /work/MLSysEngOps-NYU25Spring/tf/kvm

# %%
export PATH=/work/.local/bin:$PATH

# %%
unset $(set | grep -o "^OS_[A-Za-z0-9_]*")

# %%
export TF_VAR_suffix=zl5573
export TF_VAR_key=id_rsa_chameleon

# %%
# terraform destroy -auto-approve

# %%
terraform destroy -auto-approve \
  -target='openstack_compute_volume_attach_v2.attach_minio' \
  -target='openstack_networking_floatingip_v2.floating_ip' \
  -target='openstack_compute_instance_v2.nodes["node1"]' \
  -target='openstack_compute_instance_v2.nodes["node2"]' \
  -target='openstack_compute_instance_v2.nodes["node3"]' \
  -target='openstack_networking_port_v2.sharednet2_ports["node1"]' \
  -target='openstack_networking_port_v2.sharednet2_ports["node2"]' \
  -target='openstack_networking_port_v2.sharednet2_ports["node3"]' \
  -target='openstack_networking_port_v2.private_net_ports["node1"]' \
  -target='openstack_networking_port_v2.private_net_ports["node2"]' \
  -target='openstack_networking_port_v2.private_net_ports["node3"]' \
  -target='openstack_networking_subnet_v2.private_subnet' \
  -target='openstack_networking_network_v2.private_net'
# Out:
# data.openstack_networking_secgroup_v2.allow_8000: Reading...
# data.openstack_networking_secgroup_v2.allow_9092: Reading...
# openstack_networking_network_v2.private_net: Refreshing state... [id=9b3042fe-ac0d-48b9-ba54-c3ad06b3f926]
# data.openstack_networking_secgroup_v2.allow_3000: Reading...
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Read complete after 1s [id=d6736d54-d9a4-431c-a5b5-4d29dbcdee03]
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 1s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_secgroup_v2.allow_ssh: Read complete after 1s [id=47860acf-9269-4d26-84b1-363824f7e0a2]
# data.openstack_networking_secgroup_v2.allow_3000: Read complete after 1s [id=7884eab6-6e75-4e56-a8f0-dffc255e6b91]
# data.openstack_networking_secgroup_v2.allow_9001: Read complete after 1s [id=ad2912c0-caa9-49e0-b431-b9b3953b91b3]
# data.openstack_networking_secgroup_v2.allow_9092: Read complete after 2s [id=6969c56f-bc98-411a-bb1a-257528746028]
# data.openstack_networking_network_v2.sharednet2: Reading...
# openstack_blockstorage_volume_v3.minio_volume: Refreshing state... [id=cf7bb2f1-e28f-4491-96f4-3e95f551d306]
# data.openstack_networking_secgroup_v2.allow_8081: Read complete after 1s [id=9806d71f-f0bd-4c5d-8c48-f32db3094575]
# data.openstack_networking_secgroup_v2.allow_8000: Read complete after 2s [id=17a6d962-cc23-4551-ac0b-08b098f451d2]
# data.openstack_networking_secgroup_v2.allow_8080: Read complete after 1s [id=e6eff5db-c96d-4e3d-be49-1ade281f4a7a]
# data.openstack_networking_network_v2.sharednet2: Read complete after 0s [id=4ec616b2-79e1-4813-abca-f2ceb41e0a89]
# openstack_networking_subnet_v2.private_subnet: Refreshing state... [id=8da914e4-c1ca-428b-b80d-5cdba8dab774]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Refreshing state... [id=24e5165e-2c55-4ffa-9fac-d2afeef2ce7f]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Refreshing state... [id=d1a41259-aeee-4e75-a748-5980947bfda6]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Refreshing state... [id=55f04c11-8cf7-40b6-92a1-08a9165a36ea]
# openstack_networking_port_v2.private_net_ports["node2"]: Refreshing state... [id=6b9789a4-5068-4f8b-8457-1776b21f3598]
# openstack_networking_port_v2.private_net_ports["node3"]: Refreshing state... [id=04230edc-6e50-4258-9f0d-e8da2ba0f99a]
# openstack_networking_port_v2.private_net_ports["node1"]: Refreshing state... [id=835b8b24-d9cd-4e8d-9b5b-b79aa3952150]
# openstack_networking_floatingip_v2.floating_ip: Refreshing state... [id=0223dc4f-f3fa-4baf-a9cb-0058eb487f6f]
# openstack_compute_instance_v2.nodes["node2"]: Refreshing state... [id=d03dc49c-3cc4-490a-a3dc-f304c39e4aa8]
# openstack_compute_instance_v2.nodes["node1"]: Refreshing state... [id=116ffb4b-984e-4aab-b63a-aa8e414752f8]
# openstack_compute_instance_v2.nodes["node3"]: Refreshing state... [id=85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7]
# openstack_compute_volume_attach_v2.attach_minio: Refreshing state... [id=116ffb4b-984e-4aab-b63a-aa8e414752f8/cf7bb2f1-e28f-4491-96f4-3e95f551d306]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # openstack_compute_instance_v2.nodes["node1"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.3.97" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-11 08:57:06 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "116ffb4b-984e-4aab-b63a-aa8e414752f8" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "id_rsa_chameleon" -> null
#       - name                = "node1-mlops-zl5573-project37" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-3000",
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-9092",
#           - "allow-http-80",
#           - "allow-ssh",
#           - "default",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-11 08:57:14 +0000 UTC" -> null
#       - user_data           = "f3b5b4f9542e50ed63611e87a6d52a1f92b614c6" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.3.97" -> null
#           - mac            = "fa:16:3e:10:51:43" -> null
#           - name           = "sharednet2" -> null
#           - port           = "d1a41259-aeee-4e75-a748-5980947bfda6" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.11" -> null
#           - mac            = "fa:16:3e:48:76:fb" -> null
#           - name           = "private-net-mlops-zl5573" -> null
#           - port           = "835b8b24-d9cd-4e8d-9b5b-b79aa3952150" -> null
#           - uuid           = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node2"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.0.185" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-11 08:57:06 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "d03dc49c-3cc4-490a-a3dc-f304c39e4aa8" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "id_rsa_chameleon" -> null
#       - name                = "node2-mlops-zl5573-project37" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-3000",
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-9092",
#           - "allow-http-80",
#           - "allow-ssh",
#           - "default",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-11 08:57:14 +0000 UTC" -> null
#       - user_data           = "46549203563aea70a63dd345d05545926cc92409" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.0.185" -> null
#           - mac            = "fa:16:3e:bd:d1:89" -> null
#           - name           = "sharednet2" -> null
#           - port           = "55f04c11-8cf7-40b6-92a1-08a9165a36ea" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.12" -> null
#           - mac            = "fa:16:3e:e0:0f:31" -> null
#           - name           = "private-net-mlops-zl5573" -> null
#           - port           = "6b9789a4-5068-4f8b-8457-1776b21f3598" -> null
#           - uuid           = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_instance_v2.nodes["node3"] will be destroyed
#   - resource "openstack_compute_instance_v2" "nodes" {
#       - access_ip_v4        = "10.56.2.210" -> null
#       - all_metadata        = {} -> null
#       - all_tags            = [] -> null
#       - availability_zone   = "nova" -> null
#       - created             = "2025-05-11 08:57:07 +0000 UTC" -> null
#       - flavor_id           = "3" -> null
#       - flavor_name         = "m1.medium" -> null
#       - force_delete        = false -> null
#       - id                  = "85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7" -> null
#       - image_id            = "96d9c658-6540-4796-ae64-54d8ac6c45f8" -> null
#       - image_name          = "CC-Ubuntu24.04" -> null
#       - key_pair            = "id_rsa_chameleon" -> null
#       - name                = "node3-mlops-zl5573-project37" -> null
#       - power_state         = "active" -> null
#       - region              = "KVM@TACC" -> null
#       - security_groups     = [
#           - "allow-3000",
#           - "allow-8000",
#           - "allow-8080",
#           - "allow-8081",
#           - "allow-9001",
#           - "allow-9090",
#           - "allow-9092",
#           - "allow-http-80",
#           - "allow-ssh",
#           - "default",
#         ] -> null
#       - stop_before_destroy = false -> null
#       - tags                = [] -> null
#       - updated             = "2025-05-11 08:57:13 +0000 UTC" -> null
#       - user_data           = "e5d2eb7ae25e894016bbbc7a62381861b5e8618d" -> null
#         # (1 unchanged attribute hidden)
#
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "10.56.2.210" -> null
#           - mac            = "fa:16:3e:45:48:a4" -> null
#           - name           = "sharednet2" -> null
#           - port           = "24e5165e-2c55-4ffa-9fac-d2afeef2ce7f" -> null
#           - uuid           = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#             # (2 unchanged attributes hidden)
#         }
#       - network {
#           - access_network = false -> null
#           - fixed_ip_v4    = "192.168.1.13" -> null
#           - mac            = "fa:16:3e:2d:23:36" -> null
#           - name           = "private-net-mlops-zl5573" -> null
#           - port           = "04230edc-6e50-4258-9f0d-e8da2ba0f99a" -> null
#           - uuid           = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#             # (2 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_compute_volume_attach_v2.attach_minio will be destroyed
#   - resource "openstack_compute_volume_attach_v2" "attach_minio" {
#       - device      = "/dev/vdb" -> null
#       - id          = "116ffb4b-984e-4aab-b63a-aa8e414752f8/cf7bb2f1-e28f-4491-96f4-3e95f551d306" -> null
#       - instance_id = "116ffb4b-984e-4aab-b63a-aa8e414752f8" -> null
#       - region      = "KVM@TACC" -> null
#       - volume_id   = "cf7bb2f1-e28f-4491-96f4-3e95f551d306" -> null
#     }
#
#   # openstack_networking_floatingip_v2.floating_ip will be destroyed
#   - resource "openstack_networking_floatingip_v2" "floating_ip" {
#       - address     = "129.114.26.67" -> null
#       - all_tags    = [] -> null
#       - description = "MLOps IP for zl5573" -> null
#       - fixed_ip    = "10.56.3.97" -> null
#       - id          = "0223dc4f-f3fa-4baf-a9cb-0058eb487f6f" -> null
#       - pool        = "public" -> null
#       - port_id     = "d1a41259-aeee-4e75-a748-5980947bfda6" -> null
#       - region      = "KVM@TACC" -> null
#       - tags        = [] -> null
#       - tenant_id   = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (2 unchanged attributes hidden)
#     }
#
#   # openstack_networking_network_v2.private_net will be destroyed
#   - resource "openstack_networking_network_v2" "private_net" {
#       - admin_state_up          = true -> null
#       - all_tags                = [] -> null
#       - availability_zone_hints = [] -> null
#       - external                = false -> null
#       - id                      = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#       - mtu                     = 1450 -> null
#       - name                    = "private-net-mlops-zl5573" -> null
#       - port_security_enabled   = false -> null
#       - region                  = "KVM@TACC" -> null
#       - shared                  = false -> null
#       - tags                    = [] -> null
#       - tenant_id               = "89f528973fea4b3a981f9b2344e522de" -> null
#       - transparent_vlan        = false -> null
#         # (3 unchanged attributes hidden)
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.11",
#         ] -> null
#       - all_security_group_ids = [
#           - "833aa0fa-62f6-4eac-8ddf-510bb3441da3",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "116ffb4b-984e-4aab-b63a-aa8e414752f8" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "835b8b24-d9cd-4e8d-9b5b-b79aa3952150" -> null
#       - mac_address            = "fa:16:3e:48:76:fb" -> null
#       - name                   = "port-node1-mlops-zl5573" -> null
#       - network_id             = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.11" -> null
#           - subnet_id  = "8da914e4-c1ca-428b-b80d-5cdba8dab774" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.12",
#         ] -> null
#       - all_security_group_ids = [
#           - "833aa0fa-62f6-4eac-8ddf-510bb3441da3",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "d03dc49c-3cc4-490a-a3dc-f304c39e4aa8" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "6b9789a4-5068-4f8b-8457-1776b21f3598" -> null
#       - mac_address            = "fa:16:3e:e0:0f:31" -> null
#       - name                   = "port-node2-mlops-zl5573" -> null
#       - network_id             = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.12" -> null
#           - subnet_id  = "8da914e4-c1ca-428b-b80d-5cdba8dab774" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.private_net_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "private_net_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "192.168.1.13",
#         ] -> null
#       - all_security_group_ids = [
#           - "833aa0fa-62f6-4eac-8ddf-510bb3441da3",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "04230edc-6e50-4258-9f0d-e8da2ba0f99a" -> null
#       - mac_address            = "fa:16:3e:2d:23:36" -> null
#       - name                   = "port-node3-mlops-zl5573" -> null
#       - network_id             = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#
#       - fixed_ip {
#           - ip_address = "192.168.1.13" -> null
#           - subnet_id  = "8da914e4-c1ca-428b-b80d-5cdba8dab774" -> null
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node1"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.3.97",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "116ffb4b-984e-4aab-b63a-aa8e414752f8" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "d1a41259-aeee-4e75-a748-5980947bfda6" -> null
#       - mac_address            = "fa:16:3e:10:51:43" -> null
#       - name                   = "sharednet2-node1-mlops-zl5573" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node2"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.0.185",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "d03dc49c-3cc4-490a-a3dc-f304c39e4aa8" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "55f04c11-8cf7-40b6-92a1-08a9165a36ea" -> null
#       - mac_address            = "fa:16:3e:bd:d1:89" -> null
#       - name                   = "sharednet2-node2-mlops-zl5573" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_port_v2.sharednet2_ports["node3"] will be destroyed
#   - resource "openstack_networking_port_v2" "sharednet2_ports" {
#       - admin_state_up         = true -> null
#       - all_fixed_ips          = [
#           - "10.56.2.210",
#         ] -> null
#       - all_security_group_ids = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - all_tags               = [] -> null
#       - device_id              = "85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7" -> null
#       - device_owner           = "compute:nova" -> null
#       - dns_assignment         = [] -> null
#       - id                     = "24e5165e-2c55-4ffa-9fac-d2afeef2ce7f" -> null
#       - mac_address            = "fa:16:3e:45:48:a4" -> null
#       - name                   = "sharednet2-node3-mlops-zl5573" -> null
#       - network_id             = "4ec616b2-79e1-4813-abca-f2ceb41e0a89" -> null
#       - port_security_enabled  = true -> null
#       - region                 = "KVM@TACC" -> null
#       - security_group_ids     = [
#           - "17a6d962-cc23-4551-ac0b-08b098f451d2",
#           - "47860acf-9269-4d26-84b1-363824f7e0a2",
#           - "5df2db36-79f9-4b9b-b6c9-1ece762d83fb",
#           - "6969c56f-bc98-411a-bb1a-257528746028",
#           - "7884eab6-6e75-4e56-a8f0-dffc255e6b91",
#           - "9806d71f-f0bd-4c5d-8c48-f32db3094575",
#           - "ad2912c0-caa9-49e0-b431-b9b3953b91b3",
#           - "d6736d54-d9a4-431c-a5b5-4d29dbcdee03",
#           - "e6eff5db-c96d-4e3d-be49-1ade281f4a7a",
#         ] -> null
#       - tags                   = [] -> null
#       - tenant_id              = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (3 unchanged attributes hidden)
#
#       - binding {
#           - vif_details = {} -> null
#           - vnic_type   = "normal" -> null
#             # (3 unchanged attributes hidden)
#         }
#     }
#
#   # openstack_networking_subnet_v2.private_subnet will be destroyed
#   - resource "openstack_networking_subnet_v2" "private_subnet" {
#       - all_tags          = [] -> null
#       - cidr              = "192.168.1.0/24" -> null
#       - dns_nameservers   = [] -> null
#       - enable_dhcp       = true -> null
#       - id                = "8da914e4-c1ca-428b-b80d-5cdba8dab774" -> null
#       - ip_version        = 4 -> null
#       - name              = "private-subnet-mlops-zl5573" -> null
#       - network_id        = "9b3042fe-ac0d-48b9-ba54-c3ad06b3f926" -> null
#       - no_gateway        = true -> null
#       - region            = "KVM@TACC" -> null
#       - service_types     = [] -> null
#       - tags              = [] -> null
#       - tenant_id         = "89f528973fea4b3a981f9b2344e522de" -> null
#         # (5 unchanged attributes hidden)
#
#       - allocation_pool {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#
#       - allocation_pools {
#           - end   = "192.168.1.254" -> null
#           - start = "192.168.1.1" -> null
#         }
#     }
#
# Plan: 0 to add, 0 to change, 13 to destroy.
# openstack_compute_volume_attach_v2.attach_minio: Destroying... [id=116ffb4b-984e-4aab-b63a-aa8e414752f8/cf7bb2f1-e28f-4491-96f4-3e95f551d306]
# openstack_networking_floatingip_v2.floating_ip: Destroying... [id=0223dc4f-f3fa-4baf-a9cb-0058eb487f6f]
# openstack_networking_floatingip_v2.floating_ip: Destruction complete after 6s
# openstack_compute_volume_attach_v2.attach_minio: Destruction complete after 8s
# openstack_compute_instance_v2.nodes["node1"]: Destroying... [id=116ffb4b-984e-4aab-b63a-aa8e414752f8]
# openstack_compute_instance_v2.nodes["node3"]: Destroying... [id=85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7]
# openstack_compute_instance_v2.nodes["node2"]: Destroying... [id=d03dc49c-3cc4-490a-a3dc-f304c39e4aa8]
# openstack_compute_instance_v2.nodes["node3"]: Still destroying... [id=85beb7bc-afd3-4a3b-8403-a6ed01b5dfe7, 10s elapsed]
# openstack_compute_instance_v2.nodes["node1"]: Still destroying... [id=116ffb4b-984e-4aab-b63a-aa8e414752f8, 10s elapsed]
# openstack_compute_instance_v2.nodes["node2"]: Still destroying... [id=d03dc49c-3cc4-490a-a3dc-f304c39e4aa8, 10s elapsed]
# openstack_compute_instance_v2.nodes["node3"]: Destruction complete after 10s
# openstack_compute_instance_v2.nodes["node1"]: Destruction complete after 10s
# openstack_compute_instance_v2.nodes["node2"]: Destruction complete after 10s
# openstack_networking_port_v2.private_net_ports["node1"]: Destroying... [id=835b8b24-d9cd-4e8d-9b5b-b79aa3952150]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destroying... [id=d1a41259-aeee-4e75-a748-5980947bfda6]
# openstack_networking_port_v2.private_net_ports["node3"]: Destroying... [id=04230edc-6e50-4258-9f0d-e8da2ba0f99a]
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destroying... [id=24e5165e-2c55-4ffa-9fac-d2afeef2ce7f]
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destroying... [id=55f04c11-8cf7-40b6-92a1-08a9165a36ea]
# openstack_networking_port_v2.private_net_ports["node2"]: Destroying... [id=6b9789a4-5068-4f8b-8457-1776b21f3598]
# openstack_networking_port_v2.private_net_ports["node3"]: Destruction complete after 6s
# openstack_networking_port_v2.private_net_ports["node1"]: Destruction complete after 6s
# openstack_networking_port_v2.sharednet2_ports["node3"]: Destruction complete after 7s
# openstack_networking_port_v2.private_net_ports["node2"]: Destruction complete after 7s
# openstack_networking_port_v2.sharednet2_ports["node2"]: Destruction complete after 7s
# openstack_networking_subnet_v2.private_subnet: Destroying... [id=8da914e4-c1ca-428b-b80d-5cdba8dab774]
# openstack_networking_port_v2.sharednet2_ports["node1"]: Destruction complete after 7s
# openstack_networking_subnet_v2.private_subnet: Destruction complete after 8s
# openstack_networking_network_v2.private_net: Destroying... [id=9b3042fe-ac0d-48b9-ba54-c3ad06b3f926]
# openstack_networking_network_v2.private_net: Destruction complete after 5s
# ╷
# │ Warning: Resource targeting is in effect
# │
# │ You are creating a plan with the -target option, which means that the result
# │ of this plan may not represent all of the changes requested by the current
# │ configuration.
# │
# │ The -target option is not for routine use, and is provided only for
# │ exceptional situations such as recovering from errors or mistakes, or when
# │ Terraform specifically suggests to use it as part of an error message.
# ╵
# ╷
# │ Warning: Applied changes may be incomplete
# │
# │ The plan was created with the -target option in effect, so some changes
# │ requested in the configuration may have been ignored and the output values
# │ may not be fully updated. Run the following command to verify that no other
# │ changes are pending:
# │     terraform plan
# │
# │ Note that the -target option is not suitable for routine use, and is provided
# │ only for exceptional situations such as recovering from errors or mistakes,
# │ or when Terraform specifically suggests to use it as part of an error
# │ message.
# ╵
#
# Destroy complete! Resources: 13 destroyed.
