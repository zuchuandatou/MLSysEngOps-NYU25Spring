# %%
# git clone --recurse-submodules https://github.com/teaching-on-testbeds/gourmetgram-iac.git /work/gourmetgram-iac
# Out:
# fatal: destination path '/work/gourmetgram-iac' already exists and is not an empty directory.
# : 128

# %%
# setup terraform

# %%
mkdir -p /work/.local/bin
wget https://releases.hashicorp.com/terraform/1.10.5/terraform_1.10.5_linux_amd64.zip
unzip -o -q terraform_1.10.5_linux_amd64.zip
mv terraform /work/.local/bin
rm terraform_1.10.5_linux_amd64.zip
# Out:
# --2025-05-06 15:26:22--  https://releases.hashicorp.com/terraform/1.10.5/terraform_1.10.5_linux_amd64.zip
# Resolving releases.hashicorp.com (releases.hashicorp.com)... 18.238.171.54, 18.238.171.101, 18.238.171.95, ...
# Connecting to releases.hashicorp.com (releases.hashicorp.com)|18.238.171.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27714924 (26M) [application/zip]
# Saving to: ‘terraform_1.10.5_linux_amd64.zip’
#
# terraform_1.10.5_li 100%[===================>]  26.43M  88.0MB/s    in 0.3s
#
# 2025-05-06 15:26:23 (88.0 MB/s) - ‘terraform_1.10.5_linux_amd64.zip’ saved [27714924/27714924]

# %%
export PATH=/work/.local/bin:$PATH

# %%
terraform
# Out:
# Usage: terraform [global options] <subcommand> [args]
#
# The available commands for execution are listed below.
# The primary workflow commands are given first, followed by
# less common or more advanced commands.
#
# Main commands:
#   init          Prepare your working directory for other commands
#   validate      Check whether the configuration is valid
#   plan          Show changes required by the current configuration
#   apply         Create or update infrastructure
#   destroy       Destroy previously-created infrastructure
#
# All other commands:
#   console       Try Terraform expressions at an interactive command prompt
#   fmt           Reformat your configuration in the standard style
#   force-unlock  Release a stuck lock on the current workspace
#   get           Install or upgrade remote Terraform modules
#   graph         Generate a Graphviz graph of the steps in an operation
#   import        Associate existing infrastructure with a Terraform resource
# ...

# %%
# Define the file path
FILE_PATH="/work/MLSysEngOps-NYU25Spring/tf/kvm/clouds.yaml"
DIR_PATH=$(dirname "$FILE_PATH")

# Create the directory if it doesn't exist
mkdir -p "$DIR_PATH"

# Write the content
cat > "$FILE_PATH" <<EOF
clouds:
  openstack:
    auth:
      auth_url: https://kvm.tacc.chameleoncloud.org:5000
      application_credential_id: "2a6c503c304144cdab2dc07ef8d2cbab"
      application_credential_secret: "C65rcHWl6Dpu-ZkFe1IESSNGL56KCFM2X9K2xWXMQEyX6BcWxhuQO8FVhvPfLERCeO0Ka7XKr6KA_RHhPa1FPw"
    region_name: "KVM@TACC"
    interface: "public"
    identity_api_version: 3
    auth_type: "v3applicationcredential"
EOF

# %%
# setup ansible

# %%
PYTHONUSERBASE=/work/.local pip install --user ansible-core==2.16.9 ansible==9.8.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 16.9 MB/s eta 0:00:00
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 5.8 MB/s eta 0:00:00
#
# ...

# %%
export PATH=/work/.local/bin:$PATH
export PYTHONUSERBASE=/work/.local

# %%
ansible-playbook --help
# Out:
# usage: ansible-playbook [-h] [--version] [-v] [--private-key PRIVATE_KEY_FILE]
#                         [-u REMOTE_USER] [-c CONNECTION] [-T TIMEOUT]
#                         [--ssh-common-args SSH_COMMON_ARGS]
#                         [--sftp-extra-args SFTP_EXTRA_ARGS]
#                         [--scp-extra-args SCP_EXTRA_ARGS]
#                         [--ssh-extra-args SSH_EXTRA_ARGS]
#                         [-k | --connection-password-file CONNECTION_PASSWORD_FILE]
#                         [--force-handlers] [--flush-cache] [-b]
#                         [--become-method BECOME_METHOD]
#                         [--become-user BECOME_USER]
#                         [-K | --become-password-file BECOME_PASSWORD_FILE]
#                         [-t TAGS] [--skip-tags SKIP_TAGS] [-C] [-D]
#                         [-i INVENTORY] [--list-hosts] [-l SUBSET]
#                         [-e EXTRA_VARS] [--vault-id VAULT_IDS]
# ...

# %%
# runs in Chameleon Jupyter environment
export PATH=/work/.local/bin:$PATH
export PYTHONUSERBASE=/work/.local

# %%
# setup k8s

# %%
PYTHONUSERBASE=/work/.local pip install --user -r /work/MLSysEngOps-NYU25Spring/ansible/k8s/kubespray/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 2.1 MB/s eta 0:00:00
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.5/389.5 kB 4.7 MB/s eta 0:00:00
#
# ...

# %%
cd /work/MLSysEngOps-NYU25Spring/tf/kvm

# %%
export PATH=/work/.local/bin:$PATH

# %%
unset $(set | grep -o "^OS_[A-Za-z0-9_]*")

# %%
cat  clouds.yaml
# Out:
# clouds:
#   openstack:
#     auth:
#       auth_url: https://kvm.tacc.chameleoncloud.org:5000
#       application_credential_id: "2a6c503c304144cdab2dc07ef8d2cbab"
#       application_credential_secret: "C65rcHWl6Dpu-ZkFe1IESSNGL56KCFM2X9K2xWXMQEyX6BcWxhuQO8FVhvPfLERCeO0Ka7XKr6KA_RHhPa1FPw"
#     region_name: "KVM@TACC"
#     interface: "public"
#     identity_api_version: 3
#     auth_type: "v3applicationcredential"

# %%
terraform init
# Out:
# Initializing the backend...
# Initializing provider plugins...
# - Reusing previous version of terraform-provider-openstack/openstack from the dependency lock file
# - Using previously-installed terraform-provider-openstack/openstack v1.51.1
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
export TF_VAR_suffix=zl5573
export TF_VAR_key=id_rsa_chameleon

# %%
terraform validate
# Out:
# Success! The configuration is valid.

# %%
terraform plan
# Out:
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_secgroup_v2.allow_8000: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# data.openstack_networking_secgroup_v2.allow_3000: Reading...
# data.openstack_networking_secgroup_v2.allow_9092: Reading...
# data.openstack_networking_network_v2.sharednet2: Reading...
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_8000: Read complete after 1s [id=17a6d962-cc23-4551-ac0b-08b098f451d2]
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 1s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_secgroup_v2.allow_3000: Read complete after 1s [id=7884eab6-6e75-4e56-a8f0-dffc255e6b91]
# ...

# %%
terraform apply -auto-approve
# Out:
# data.openstack_networking_network_v2.sharednet2: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Reading...
# data.openstack_networking_subnet_v2.sharednet2_subnet: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Reading...
# data.openstack_networking_secgroup_v2.allow_8081: Reading...
# data.openstack_networking_secgroup_v2.allow_8080: Reading...
# data.openstack_networking_secgroup_v2.allow_3000: Reading...
# data.openstack_networking_secgroup_v2.allow_9090: Reading...
# openstack_networking_network_v2.private_net: Refreshing state... [id=7042649f-e658-4376-9e44-ec7d24cc0e14]
# data.openstack_networking_secgroup_v2.allow_ssh: Reading...
# data.openstack_networking_secgroup_v2.allow_http_80: Read complete after 0s [id=5df2db36-79f9-4b9b-b6c9-1ece762d83fb]
# data.openstack_networking_secgroup_v2.allow_9092: Reading...
# data.openstack_networking_secgroup_v2.allow_9001: Read complete after 0s [id=ad2912c0-caa9-49e0-b431-b9b3953b91b3]
# ...

# %%
terraform output
# Out:
# floating_ip_out = "129.114.26.200"

# %%
FLOATING_IP=$(terraform output -raw floating_ip_out)

# Define ansible.cfg destination
CFG_PATH="/work/MLSysEngOps-NYU25Spring/ansible/ansible.cfg"

# Create ansible.cfg with IP dynamically inserted
cat > "$CFG_PATH" <<EOF
[defaults]
stdout_callback = yaml
inventory = /work/gourmetgram-iac/ansible/inventory.yaml

[ssh_connection]
ssh_args = -o StrictHostKeyChecking=off -o UserKnownHostsFile=/dev/null -o ForwardAgent=yes -o ProxyCommand="ssh -o StrictHostKeyChecking=no -o UserKnownHostsFile=/dev/null -W %h:%p cc@$FLOATING_IP"
EOF

echo "Generated ansible.cfg with floating IP $FLOATING_IP"
# Out:
# Generated ansible.cfg with floating IP 129.114.26.200

# %%
# use ansible to deploy k8s & ArgoCD

# %%
export PATH=/work/.local/bin:$PATH
export PYTHONUSERBASE=/work/.local

# %%
cat /work/MLSysEngOps-NYU25Spring/ansible/ansible.cfg
# Out:
# [defaults]
# stdout_callback = yaml
# inventory = /work/gourmetgram-iac/ansible/inventory.yaml
#
# [ssh_connection]
# ssh_args = -o StrictHostKeyChecking=off -o UserKnownHostsFile=/dev/null -o ForwardAgent=yes -o ProxyCommand="ssh -o StrictHostKeyChecking=no -o UserKnownHostsFile=/dev/null -W %h:%p cc@129.114.26.200"

# %%
cd /work/MLSysEngOps-NYU25Spring/ansible

# %%
ansible -i inventory.yml all -m ping
# Out:
# node3 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# node1 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# node2 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }

# %%
cd /work/MLSysEngOps-NYU25Spring/ansible
ansible-playbook -i inventory.yml pre_k8s/pre_k8s_configure.yml
# Out:
# PLAY [Disable and Mask firewalld] **********************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [node2]
# ok: [node3]
# ok: [node1]
#
# TASK [Stop firewalld service] **************************************************
# changed: [node2]
# changed: [node3]
# changed: [node1]
#
# TASK [Mask firewalld service] **************************************************
# changed: [node1]
# changed: [node3]
# changed: [node2]
#
# PLAY [Set up insecure registry for Docker] *************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [node1]
# ok: [node3]
# ok: [node2]
#
# TASK [Ensure /etc/docker directory exists] *************************************
# changed: [node1]
# changed: [node2]
# changed: [node3]
#
# TASK [Create /etc/docker/daemon.json if not exists] ****************************
# changed: [node1]
# changed: [node3]
# changed: [node2]
#
# ...

# %%
export ANSIBLE_CONFIG=/work/MLSysEngOps-NYU25Spring/ansible/ansible.cfg
export ANSIBLE_ROLES_PATH=roles

# %%
cd /work/MLSysEngOps-NYU25Spring/ansible/k8s/kubespray
ansible-playbook -i ../inventory/mycluster --become --become-user=root ./cluster.yml
# Out:
# [WARNING]: While constructing a mapping from /work/MLSysEngOps-
# NYU25Spring/ansible/k8s/kubespray/roles/bootstrap-os/tasks/main.yml, line 29,
# column 7, found a duplicate dict key (paths). Using last defined value only.
#
# PLAY [Check Ansible version] ***************************************************
#
# TASK [Check 2.16.4 <= Ansible version < 2.17.0] ********************************
# ok: [node1] => changed=false
#   msg: All assertions passed
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [node1] => changed=false
#   msg: All assertions passed
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [node1] => changed=false
#   msg: All assertions passed
# [WARNING]: Could not match supplied host pattern, ignoring: kube-master
#
# PLAY [Add kube-master nodes to kube_control_plane] *****************************
# skipping: no hosts matched
# ...

# %%
cd /work/MLSysEngOps-NYU25Spring/ansible
ansible-playbook -i inventory.yml post_k8s/post_k8s_configure.yml
# Out:
# PLAY [Post-Install kubectl Setup] **********************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [node1]
# ok: [node2]
#
# TASK [Ensure .kube directory exists] *******************************************
# changed: [node1]
# changed: [node2]
#
# TASK [Copy admin.conf to user's kubeconfig] ************************************
# changed: [node2]
# changed: [node1]
#
# TASK [Run kubectl get nodes as cc] *********************************************
# changed: [node1]
# changed: [node2]
#
# TASK [Show kubectl get nodes output] *******************************************
# ok: [node1] =>
#   msg:
#   - NAME    STATUS   ROLES           AGE   VERSION
#   - node1   Ready    control-plane   25m   v1.30.6
#   - node2   Ready    control-plane   24m   v1.30.6
#   - node3   Ready    <none>          22m   v1.30.6
# ok: [node2] =>
#   msg:
#   - NAME    STATUS   ROLES           AGE   VERSION
# ...

# %%
# use ansible to let argocd setup platform (minio, postgres, mlflow)

# %%
export PATH=/work/.local/bin:$PATH
export PYTHONUSERBASE=/work/.local
export ANSIBLE_CONFIG=/work/MLSysEngOps-NYU25Spring/ansible/ansible.cfg
export ANSIBLE_ROLES_PATH=roles

# %%
cd /work/MLSysEngOps-NYU25Spring/ansible
ansible-playbook -i inventory.yml argocd/argocd_add_platform.yml
# Out:
# PLAY [Mount persistent volume and deploy MLflow platform with MinIO] ***********
#
# TASK [Gathering Facts] *********************************************************
# ok: [node1]
#
# TASK [Detect existing filesystem] **********************************************
# ok: [node1]
#
# TASK [Format device as ext4 (first boot only)] *********************************
# skipping: [node1]
#
# TASK [Create mount directory] **************************************************
# ok: [node1]
#
# TASK [Mount volume now and on every reboot] ************************************
# changed: [node1]
#
# PLAY [Deploy MLflow platform via ArgoCD & Helm with MinIO secret handling] *****
#
# TASK [Gathering Facts] *********************************************************
# ok: [node1]
#
# TASK [Get ArgoCD admin password from Kubernetes secret] ************************
# changed: [node1]
#
# TASK [Decode ArgoCD admin password] ********************************************
# changed: [node1]
#
# ...
